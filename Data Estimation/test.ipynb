# %%
import numpy as np

import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# ## Plotting d1

# %%
x = []
y = []
with open("d1.txt", "r") as file:
    data = file.readlines()
    for i in data:
        x.append(float(i.split(",")[0]))
        y.append(float(i.split(",")[1].strip()))


x = np.array(x)
y = np.array(y)

plt.plot(x, y)

# %% [markdown]
# ## Plotting d2

# %%
x = []
y = []
with open("d2.txt", "r") as file:
    data = file.readlines()
    for i in data:
        x.append(float(i.split(",")[0]))
        y.append(float(i.split(",")[1].strip()))


x = np.array(x)
y = np.array(y)

plt.plot(x, y)

# %% [markdown]
# ## Plotting d4

# %%
x = []
y = []
with open("d4.txt", "r") as file:
    data = file.readlines()
    for i in data:
        x.append(float(i.split(",")[0]))
        y.append(float(i.split(",")[1].strip()))


x = np.array(x)
y = np.array(y)

plt.plot(x, y)

# %% [markdown]
# ## Plotting d3

# %%
x = []
y = []
with open("d3.txt", "r") as file:
    data = file.readlines()
    for i in data:
        x.append(float(i.split(",")[0]))
        y.append(float(i.split(",")[1].strip()))

x = np.array(x)
# x *= np.power(10,6)
y = np.array(y)
x_cut = x[100:]
y_cut = y[100:]
plt.plot(x_cut, y_cut)

# %% [markdown]
# ## generating the fucntion

# %%
def planksLaw(Ld, T,h,c, k ):
    B = (2*h*np.power(c,2))/(np.power(Ld,5)*(np.exp(h*c/(Ld*k*T))-1))
    return B

# %%
p0 = np.array([1000,1e-20,3e8,1e-10])
params, params_covariance = sp.optimize.curve_fit(planksLaw, x_cut, y_cut, p0 = p0)

# %%
print(params)
plt.figure(); plt.plot(x, y); plt.plot(x[50:], planksLaw(x[50:], *params))
# plt.plot(x_cut, y_cut)
# Out:
# [1.17121834e+02 1.19548134e-20 6.91610429e+01 1.97760970e-15]

# %%
print(params)
# Out:
# [1.17121834e+02 1.19548134e-20 6.91610429e+01 1.97760970e-15]

# %% [markdown]
# ### let us fix every other variable

# %%
initparams = np.array([6.64*1e-34, 3*1e8,1.38e-23 ])

def newFun(Ld, T):
    return planksLaw(Ld,T, *initparams)

params, params_covariance = sp.optimize.curve_fit(newFun, x, y, p0 = [4000])

# %% [markdown]
# ##
